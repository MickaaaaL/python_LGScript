# %% [markdown]
# # 00 — Configuration de votre poste
#
# Bienvenue ! Ce notebook **se lance une seule fois en début de formation**.
# Il enregistre votre identité localement et vous rattache à la session de
# formation pour que vos exercices soient suivis par le formateur.

# %% [markdown]
# ## Ce dont vous avez besoin
#
# 1. **Votre nom complet** (tel qu'il apparaîtra sur le tableau de bord du formateur).
# 2. **Le code de session** communiqué par votre formateur en début de stage.
#    Il ressemble à `INIT-17MAR-K3F9` (formation + date + identifiant court).
#
# Si vous n'avez pas encore le code, demandez-le à votre formateur avant d'aller plus loin.

# %% [markdown]
# ## Étape 1 — Renseignez vos informations
#
# Modifiez les deux variables ci-dessous puis exécutez la cellule (`Shift + Entrée`).

# %%
NOM = "Mickaël RAKOTOARIMANGA"            # remplacez par votre nom complet
SESSION = "INIT-01JUN-3B8A"   # remplacez par le code donné par le formateur

# %% [markdown]
# ## Étape 2 — Enregistrez votre configuration
#
# Cette cellule appelle le serveur `notebooks.inspyration.net` pour vous inscrire
# à la session. Si tout va bien, vous verrez un message ✅.

# %%
import sys
from pathlib import Path

# Permet de trouver utils_pedagogie.py dans _common/ quel que soit l'emplacement du notebook
for candidate in (Path.cwd(), *Path.cwd().parents):
    if (candidate / "_common" / "utils_pedagogie.py").exists():
        sys.path.insert(0, str(candidate / "_common"))
        break

from utils_pedagogie import configurer

configurer(nom=NOM, session=SESSION)
# Out:
# ✅ Bonjour Mickaël RAKOTOARIMANGA, session « INIT-01JUN-3B8A » rejointe.
#    Vos exercices seront suivis par le formateur.

# %% [markdown]
# ## Étape 3 — Vérification
#
# Si le message ci-dessus indique :
#
# - ✅ **« session rejointe »** : tout est bon, vous pouvez fermer ce notebook et
#   ouvrir le premier notebook d'exercice. Vos résultats remonteront
#   automatiquement vers le formateur.
# - ⚠ **« Serveur indisponible ou session inconnue »** : deux causes possibles :
#   - le **code de session est incorrect** → vérifiez-le auprès du formateur et
#     relancez la cellule précédente,
#   - vous n'avez **pas d'accès Internet** → vos exercices fonctionneront
#     quand même en *mode hors ligne*, et seront envoyés au formateur dès le
#     rétablissement de la connexion (rien à faire de spécial).

# %% [markdown]
# ## À savoir
#
# - La configuration est sauvegardée dans `~/.python_support/config.json` ;
#   tous les notebooks de la formation y accèdent automatiquement.
# - Pour **changer de formation** plus tard (autre session, autre semaine),
#   réexécutez simplement ce notebook avec le nouveau code de session.
# - Vos données personnelles (nom, résultats) sont **anonymisées
#   automatiquement** au plus tard à la date de purge prévue pour votre
#   formation, conformément au RGPD.
