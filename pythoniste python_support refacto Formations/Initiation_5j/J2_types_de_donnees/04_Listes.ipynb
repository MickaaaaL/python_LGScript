# %% [markdown]
# # 04 — Les listes
#
# ## Objectifs pédagogiques
#
# À la fin de ce notebook, vous saurez :
#
# - créer une liste avec `[...]` et `list()` ;
# - accéder aux éléments par **index** et par **slicing** ;
# - ajouter, supprimer et modifier des éléments (`append`, `insert`, `pop`, `remove`) ;
# - trier avec `sort()` et `sorted()` ;
# - écrire des **compréhensions de liste** basiques ;
# - reconnaître les pièges courants liés à la mutabilité.

# %% [markdown]
# ## Prérequis — ce que vous connaissez déjà
#
# À ce stade de la formation, vous savez :
#
# - déclarer des variables et affecter des valeurs ;
# - utiliser `print(...)` et les **f-strings** pour afficher ;
# - utiliser `input(...)` et les conversions `int()` / `float()` ;
# - écrire des conditions (`if`, `elif`, `else`) ;
# - écrire des boucles (`for`, `while`, `break`, `continue`, `range`) ;
# - manipuler les types `int`, `float`, `bool`, `str` et leurs méthodes.
#
# Ce que nous n'avons **pas encore vu** (et que nous n'utiliserons donc pas dans ce notebook) :
#
# - les tuples, dictionnaires, ensembles ;
# - les fonctions (`def`) et les type hints ;
# - les compréhensions imbriquées complexes ;
# - la gestion d'exceptions (`try` / `except`).

# %% [markdown]
# ## Plan
#
# 1. Créer une liste
# 2. Accéder aux éléments (index et slicing)
# 3. Modifier une liste (mutabilité)
# 4. Méthodes de liste — ajout et suppression
# 5. Méthodes de liste — recherche et comptage
# 6. Trier une liste
# 7. Itérer sur une liste
# 8. Compréhensions de liste
# 9. Pièges courants
# 10. Synthèse
# 11. Exercices

# %% [markdown]
# ---
#
# ## 1. Créer une liste
#
# Une liste est une **séquence ordonnée et modifiable** d'éléments. On la crée avec des crochets `[...]`.

# %%
fruits = ["pomme", "banane", "cerise"]

# %%
print(fruits)

# %%
type(fruits)

# %% [markdown]
# Une liste peut contenir des éléments de **types différents**.

# %%
melange = [42, 3.14, "hello", True]

# %%
print(melange)

# %% [markdown]
# La liste vide se crée avec `[]` ou `list()`.

# %%
vide_1 = []

# %%
vide_2 = list()

# %%
print(vide_1, vide_2)

# %% [markdown]
# `list()` peut aussi convertir un itérable en liste.

# %%
list(range(5))

# %%
list("Python")

# %% [markdown]
# La fonction `len()` donne le nombre d'éléments.

# %%
len(fruits)

# %% [markdown]
# ---
#
# ## 2. Accéder aux éléments
#
# ### Index positif
#
# Les éléments sont numérotés à partir de **0**.

# %%
fruits[0]

# %%
fruits[1]

# %%
fruits[2]

# %% [markdown]
# ### Index négatif
#
# Un index négatif compte depuis la fin : `-1` est le dernier élément.

# %%
fruits[-1]

# %%
fruits[-2]

# %% [markdown]
# ### Slicing (tranches)
#
# La syntaxe `liste[debut:fin]` extrait une sous-liste. `debut` est inclus, `fin` est **exclu**.

# %%
nombres = [10, 20, 30, 40, 50, 60, 70]

# %%
nombres[1:4]

# %%
nombres[:3]   # du début jusqu'à l'index 3 (exclu)

# %%
nombres[4:]   # de l'index 4 jusqu'à la fin

# %%
nombres[::2]  # un élément sur deux

# %%
nombres[::-1] # liste inversée

# %% [markdown]
# ### Slicing avec un pas négatif

# %%
nombres[5:1:-1]  # de l'index 5 à l'index 2 (1 exclu), à reculons

# %%
nombres[6:0:-2]  # de la fin vers le début, un sur deux

# %% [markdown]
# ---
#
# ## 3. Modifier une liste (mutabilité)
#
# Contrairement aux chaînes de caractères, les listes sont **mutables** : on peut modifier un élément en place.

# %%
fruits[1] = "fraise"

# %%
print(fruits)

# %% [markdown]
# On peut aussi remplacer une tranche entière.

# %%
nombres[1:3] = [200, 300]

# %%
print(nombres)

# %% [markdown]
# ---
#
# ## 4. Méthodes de liste — ajout et suppression
#
# ### `append()` — ajouter à la fin

# %%
fruits.append("kiwi")

# %%
print(fruits)

# %% [markdown]
# ### `insert()` — ajouter à un index précis

# %%
fruits.insert(1, "mangue")

# %%
print(fruits)

# %% [markdown]
# ### `extend()` — ajouter plusieurs éléments

# %%
fruits.extend(["ananas", "litchi"])

# %%
print(fruits)

# %% [markdown]
# L'opérateur `+` crée une **nouvelle** liste (ne modifie pas l'originale).

# %%
a = [1, 2]
b = [3, 4]
c = a + b

# %%
print(c)

# %%
print(a)  # a n'a pas changé

# %% [markdown]
# ### `pop()` — retirer par index (et récupérer la valeur)

# %%
dernier = fruits.pop()

# %%
print(dernier)

# %%
print(fruits)

# %%
deuxieme = fruits.pop(1)

# %%
print(deuxieme)

# %% [markdown]
# ### `remove()` — retirer par valeur
#
# Supprime la **première** occurrence.

# %%
fruits.remove("kiwi")

# %%
print(fruits)

# %% [markdown]
# ### `clear()` — vider la liste

# %%
copie = ["a", "b", "c"]
copie.clear()

# %%
print(copie)

# %% [markdown]
# ### `del` — supprimer par index ou par tranche

# %%
nums = [10, 20, 30, 40, 50]
del nums[2]

# %%
print(nums)

# %% [markdown]
# ---
#
# ## 5. Méthodes de liste — recherche et comptage
#
# ### `in` — vérifier la présence

# %%
"pomme" in fruits

# %%
"mangue" in fruits

# %% [markdown]
# ### `index()` — trouver la position

# %%
fruits.index("pomme")

# %% [markdown]
# ### `count()` — compter les occurrences

# %%
notes = [12, 15, 12, 18, 12, 9]
notes.count(12)

# %% [markdown]
# ---
#
# ## 6. Trier une liste
#
# ### `sort()` — tri en place (modifie la liste)
#
# `sort()` ne retourne rien (`None`), il modifie la liste directement.

# %%
notes.sort()

# %%
print(notes)

# %% [markdown]
# Tri décroissant avec `reverse=True`.

# %%
notes.sort(reverse=True)

# %%
print(notes)

# %% [markdown]
# ### `sorted()` — tri qui crée une nouvelle liste
#
# `sorted()` retourne une **nouvelle** liste triée, l'originale ne change pas.

# %%
original = [3, 1, 4, 1, 5, 9]
trie = sorted(original)

# %%
print(trie)

# %%
print(original)  # inchangé

# %% [markdown]
# ### `reverse()` — inverser en place

# %%
original.reverse()

# %%
print(original)

# %% [markdown]
# ### Tri avec clé personnalisée

# %% [markdown]
# On peut passer une fonction `key` à `sort()` / `sorted()`. Par exemple, trier des mots par longueur :

# %%
mots = ["banane", "kiwi", "fraise", "pomme"]
print(sorted(mots, key=len))

# %% [markdown]
# ---
#
# ## 7. Itérer sur une liste
#
# ### Boucle `for` simple

# %%
couleurs = ["rouge", "vert", "bleu"]
for c in couleurs:
    print(c)

# %% [markdown]
# ### `enumerate()` — index + valeur

# %%
for i, c in enumerate(couleurs):
    print(f"{i} : {c}")

# %% [markdown]
# ### `zip()` — parcourir deux listes en parallèle

# %%
prenoms = ["Alice", "Bob", "Charlie"]
ages = [25, 30, 35]
for prenom, age in zip(prenoms, ages):
    print(f"{prenom} a {age} ans")

# %% [markdown]
# ### Fonctions utiles sur les listes numériques

# %%
valeurs = [4, 8, 2, 9, 1]

# %%
sum(valeurs)

# %%
min(valeurs)

# %%
max(valeurs)

# %% [markdown]
# ---
#
# ## 8. Compréhensions de liste
#
# Une **compréhension de liste** (list comprehension) crée une liste en une seule expression.
#
# Syntaxe : `[expression for element in iterable]`

# %%
carres = [x ** 2 for x in range(6)]

# %%
print(carres)

# %% [markdown]
# Avec une **condition de filtrage** : `[expression for element in iterable if condition]`

# %%
pairs = [x for x in range(10) if x % 2 == 0]

# %%
print(pairs)

# %% [markdown]
# On peut appliquer une transformation et un filtre en même temps.

# %%
longueurs = [len(m) for m in ["chat", "chien", "oiseau", "rat"]]
print(longueurs)

# %% [markdown]
# ### Compréhension avec f-string

# %%
etiquettes = [f"item_{i}" for i in range(1, 6)]
print(etiquettes)

# %% [markdown]
# ### Équivalence avec une boucle classique
#
# Chaque compréhension peut se réécrire en boucle (et vice-versa).

# %%
# Boucle classique
resultat = []
for x in range(6):
    resultat.append(x ** 2)
print(resultat)

# %% [markdown]
# ---
#
# ## 9. Pièges courants
#
# ### Piège 1 : copie par référence
#
# Affecter une liste à une autre variable ne crée **pas** de copie.

# %%
a = [1, 2, 3]
b = a          # b pointe vers la MÊME liste
b.append(4)

# %%
print(a)  # a est aussi modifié !

# %% [markdown]
# Pour faire une **vraie copie**, utiliser `.copy()` ou le slicing `[:]`.

# %%
a = [1, 2, 3]
b = a.copy()   # copie indépendante
b.append(4)

# %%
print(a)  # a n'a pas changé

# %%
print(b)

# %% [markdown]
# ### Piège 2 : multiplication de listes imbriquées

# %%
# Piège : les sous-listes sont les MÊMES objets
grille = [[0] * 3] * 3
grille[0][0] = 1
print(grille)  # toutes les lignes changent !

# %%
# Solution : compréhension de liste
grille = [[0] * 3 for _ in range(3)]
grille[0][0] = 1
print(grille)  # seule la première ligne change

# %% [markdown]
# ### Piège 3 : modifier une liste en la parcourant

# %%
# Ne faites pas ça :
# for x in ma_liste:
#     if condition:
#         ma_liste.remove(x)  # comportement imprévisible

# Utilisez une compréhension :
nombres = [1, 2, 3, 4, 5, 6]
nombres = [x for x in nombres if x % 2 != 0]
print(nombres)

# %% [markdown]
# ---
#
# ## 10. Synthèse
#
# | Opération | Syntaxe | Modifie la liste ? |
# |---|---|---|
# | Créer | `[1, 2, 3]` ou `list(...)` | — |
# | Accéder | `liste[i]`, `liste[a:b]` | Non |
# | Modifier | `liste[i] = val` | **Oui** |
# | Ajouter | `append()`, `insert()`, `extend()` | **Oui** |
# | Supprimer | `pop()`, `remove()`, `del` | **Oui** |
# | Chercher | `in`, `index()`, `count()` | Non |
# | Trier | `sort()` | **Oui** |
# | Trier (copie) | `sorted()` | Non (nouvelle liste) |
# | Compréhension | `[expr for x in iter]` | Non (nouvelle liste) |
#
# ### Règles à retenir
#
# 1. Les listes sont **mutables** : les méthodes comme `append`, `sort`, `remove` modifient la liste en place.
# 2. `sorted()` crée une **nouvelle** liste ; `sort()` modifie l'existante.
# 3. Attention aux **copies par référence** : `b = a` ne copie pas, `b = a.copy()` copie.
# 4. Les compréhensions de liste sont plus **lisibles** et **rapides** qu'une boucle + `append`.

# %% [markdown]
# ---
#
# ## 11. Exercices
#
# Chaque exercice est un **script** à écrire dans une cellule de code. Les f-strings sont disponibles pour l'affichage.
#
# Pour chaque exercice : essayez d'abord par vous-même. Quand votre script fonctionne, cliquez sur « Voir la correction » pour comparer.

# %% [markdown]
# ### Exercice 1 — Somme et moyenne *(facile)*
#
# Écrire un script qui crée une liste de 5 nombres (au choix), puis affiche :
# - la somme (avec `sum()`) ;
# - la moyenne (somme divisée par `len()`) ;
# - le minimum et le maximum.

# %%
# Votre code ici

# %%
# ▶ Une fois votre solution écrite ci-dessus, exécutez cette cellule
# pour signaler à votre formateur que vous avez tenté l'exercice.
import sys
from pathlib import Path
for _p in (Path.cwd(), *Path.cwd().parents):
    if (_p / "_common" / "utils_pedagogie.py").exists():
        sys.path.insert(0, str(_p / "_common")); break
from utils_pedagogie import marquer_tentative
marquer_tentative(notebook="04_Listes", exercice=1)

# %% [markdown]
# <details>
# <summary>📖 Voir la correction</summary>
#
# ```python
# notes = [14, 8, 17, 11, 15]
# print(f"Somme : {sum(notes)}")
# print(f"Moyenne : {sum(notes) / len(notes)}")
# print(f"Min : {min(notes)}, Max : {max(notes)}")
# ```
#
# </details>

# %% [markdown]
# ### Exercice 2 — Filtrer les pairs *(facile)*
#
# Écrire un script qui, à partir de `list(range(1, 21))`, crée une nouvelle liste contenant uniquement les nombres pairs (avec une compréhension de liste). Afficher le résultat.

# %%
# Votre code ici

# %%
# ▶ Une fois votre solution écrite ci-dessus, exécutez cette cellule
# pour signaler à votre formateur que vous avez tenté l'exercice.
import sys
from pathlib import Path
for _p in (Path.cwd(), *Path.cwd().parents):
    if (_p / "_common" / "utils_pedagogie.py").exists():
        sys.path.insert(0, str(_p / "_common")); break
from utils_pedagogie import marquer_tentative
marquer_tentative(notebook="04_Listes", exercice=2)

# %% [markdown]
# <details>
# <summary>📖 Voir la correction</summary>
#
# ```python
# nombres = list(range(1, 21))
# pairs = [x for x in nombres if x % 2 == 0]
# print(f"Pairs : {pairs}")
# ```
#
# </details>

# %% [markdown]
# ### Exercice 3 — Inverser une liste manuellement *(moyen)*
#
# Écrire un script qui inverse une liste **sans utiliser** `reverse()`, `reversed()`, ni le slicing `[::-1]`. Utilisez une boucle.

# %%
# Votre code ici

# %%
# ▶ Une fois votre solution écrite ci-dessus, exécutez cette cellule
# pour signaler à votre formateur que vous avez tenté l'exercice.
import sys
from pathlib import Path
for _p in (Path.cwd(), *Path.cwd().parents):
    if (_p / "_common" / "utils_pedagogie.py").exists():
        sys.path.insert(0, str(_p / "_common")); break
from utils_pedagogie import marquer_tentative
marquer_tentative(notebook="04_Listes", exercice=3)

# %% [markdown]
# <details>
# <summary>📖 Voir la correction</summary>
#
# ```python
# originale = [10, 20, 30, 40, 50]
# inversee = []
# for i in range(len(originale) - 1, -1, -1):
#     inversee.append(originale[i])
# print(f"Inversée : {inversee}")
# ```
#
# </details>

# %% [markdown]
# ### Exercice 4 — Supprimer les doublons *(moyen)*
#
# Écrire un script qui prend une liste contenant des doublons et crée une nouvelle liste sans doublons, **en conservant l'ordre d'apparition**.
#
# **Indice :** parcourez la liste et n'ajoutez un élément que s'il n'est pas déjà dans la nouvelle liste (`not in`).

# %%
# Votre code ici

# %%
# ▶ Une fois votre solution écrite ci-dessus, exécutez cette cellule
# pour signaler à votre formateur que vous avez tenté l'exercice.
import sys
from pathlib import Path
for _p in (Path.cwd(), *Path.cwd().parents):
    if (_p / "_common" / "utils_pedagogie.py").exists():
        sys.path.insert(0, str(_p / "_common")); break
from utils_pedagogie import marquer_tentative
marquer_tentative(notebook="04_Listes", exercice=4)

# %% [markdown]
# <details>
# <summary>📖 Voir la correction</summary>
#
# ```python
# avec_doublons = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5]
# sans_doublons = []
# for x in avec_doublons:
#     if x not in sans_doublons:
#         sans_doublons.append(x)
# print(f"Sans doublons : {sans_doublons}")
# ```
#
# </details>

# %% [markdown]
# ### Exercice 5 — Matrice en compréhension *(moyen)*
#
# Écrire un script qui crée une liste de listes représentant la table de multiplication de 1 à 5 :
#
# ```
# [[1, 2, 3, 4, 5],
#  [2, 4, 6, 8, 10],
#  [3, 6, 9, 12, 15],
#  [4, 8, 12, 16, 20],
#  [5, 10, 15, 20, 25]]
# ```
#
# Puis affichez chaque ligne.

# %%
# Votre code ici

# %%
# ▶ Une fois votre solution écrite ci-dessus, exécutez cette cellule
# pour signaler à votre formateur que vous avez tenté l'exercice.
import sys
from pathlib import Path
for _p in (Path.cwd(), *Path.cwd().parents):
    if (_p / "_common" / "utils_pedagogie.py").exists():
        sys.path.insert(0, str(_p / "_common")); break
from utils_pedagogie import marquer_tentative
marquer_tentative(notebook="04_Listes", exercice=5)

# %% [markdown]
# <details>
# <summary>📖 Voir la correction</summary>
#
# ```python
# table = [[i * j for j in range(1, 6)] for i in range(1, 6)]
# for ligne in table:
#     print(ligne)
# ```
#
# </details>

# %% [markdown]
# ### Exercice 6 — Tri de notes avec seuil *(difficile)*
#
# Écrire un script qui :
#
# 1. part d'une liste de notes (entières, entre 0 et 20) ;
# 2. sépare les notes en deux listes : « admis » (>= 10) et « recalés » (< 10) ;
# 3. trie chaque liste par ordre décroissant ;
# 4. affiche les deux listes et le nombre d'étudiants dans chaque catégorie.

# %%
# Votre code ici

# %%
# ▶ Une fois votre solution écrite ci-dessus, exécutez cette cellule
# pour signaler à votre formateur que vous avez tenté l'exercice.
import sys
from pathlib import Path
for _p in (Path.cwd(), *Path.cwd().parents):
    if (_p / "_common" / "utils_pedagogie.py").exists():
        sys.path.insert(0, str(_p / "_common")); break
from utils_pedagogie import marquer_tentative
marquer_tentative(notebook="04_Listes", exercice=6)

# %% [markdown]
# <details>
# <summary>📖 Voir la correction</summary>
#
# ```python
# notes = [12, 7, 15, 3, 18, 9, 14, 6, 11, 16, 8, 10]
# admis = sorted([n for n in notes if n >= 10], reverse=True)
# recales = sorted([n for n in notes if n < 10], reverse=True)
# print(f"Admis ({len(admis)}) : {admis}")
# print(f"Recalés ({len(recales)}) : {recales}")
# ```
#
# </details>

# %% [markdown]
# ### Exercice 7 — Liste de courses interactive *(difficile)*
#
# Écrire un script qui simule une liste de courses. Dans une boucle :
#
# 1. afficher le menu : `a` (ajouter), `s` (supprimer), `l` (lister), `q` (quitter) ;
# 2. selon le choix, demander l'article et modifier la liste ;
# 3. quitter proprement avec `q`.
#
# **Contrainte :** gérer le cas où on essaie de supprimer un article absent.

# %%
# Votre code ici

# %%
# ▶ Une fois votre solution écrite ci-dessus, exécutez cette cellule
# pour signaler à votre formateur que vous avez tenté l'exercice.
import sys
from pathlib import Path
for _p in (Path.cwd(), *Path.cwd().parents):
    if (_p / "_common" / "utils_pedagogie.py").exists():
        sys.path.insert(0, str(_p / "_common")); break
from utils_pedagogie import marquer_tentative
marquer_tentative(notebook="04_Listes", exercice=7)

# %% [markdown]
# <details>
# <summary>📖 Voir la correction</summary>
#
# ```python
# courses = []
#
# while True:
#     choix = input("(a)jouter, (s)upprimer, (l)ister, (q)uitter : ")
#     if choix == "q":
#         print("Au revoir !")
#         break
#     elif choix == "a":
#         article = input("Article à ajouter : ")
#         courses.append(article)
#         print(f"'{article}' ajouté.")
#     elif choix == "s":
#         article = input("Article à supprimer : ")
#         if article in courses:
#             courses.remove(article)
#             print(f"'{article}' supprimé.")
#         else:
#             print(f"'{article}' n'est pas dans la liste.")
#     elif choix == "l":
#         if courses:
#             for i, art in enumerate(courses, 1):
#                 print(f"  {i}. {art}")
#         else:
#             print("  (liste vide)")
#     else:
#         print("Choix non reconnu.")
# ```
#
# </details>

# %% [markdown]
# ---
#
# ## Ressources externes
#
# ### Documentation officielle Python
#
# - [Les listes — doc Python](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists)
# - [Type `list` — doc Python](https://docs.python.org/3/library/stdtypes.html#list)
# - [Compréhensions de liste — doc Python](https://docs.python.org/3/tutorial/datastructures.html#list-comprehensions)
#
# ### À voir absolument
#
# - [Visualiser l'exécution pas à pas](https://pythontutor.com/) — Python Tutor, idéal pour comprendre les références et la mutabilité.
